# %% [markdown]
# <a href="https://colab.research.google.com/github/daniela0729/talento-tech/blob/main/Practica_Daniela_pyton_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# paso 1: conectar  drive a colb
# paso 2 : importar la libreria path y file con la ruta del archivo
# paso 3 : importar a pandas
# paso 4 : df conectar con excel  y despues se pone . y head  para que lea datos
# paso 5 : experimento con diferentes comandos

# %%
# Paso 1
from google.colab import drive # Traemos la clase drive, dentro del módulo colab, del paquete google
drive.mount('/content/drive') # Establecemos la conexión através del método mount
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#paso 2:
path = '/content/drive/MyDrive/Colab Notebooks/ventass.xlsx'
file = 'ventass .xlsx'

# %%
#paso 3:
import pandas as pd

# %%
# paso 4 :
df = pd.read_excel(path)

# %%
df.head(20)
# Out:
#      Region      Producto Vendedor  Ventas
# 0   Central    Accesorios    David    8287
# 1   Central    Accesorios    Karen    6909
# 2   Central  Dispositivos    David   11420
# 3   Central  Dispositivos    Karen   12948
# 4   Central      Sistemas    David   20098
# 5   Central      Sistemas    Karen   30633
# 6      Este    Accesorios      Ana    9323
# 7      Este    Accesorios    Lucas    7667
# 8      Este  Dispositivos      Ana   10348
# 9      Este  Dispositivos    Lucas    9312
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 12    Oeste    Accesorios    Kevin    4744
# 13    Oeste    Accesorios     Sara    5442
# 14    Oeste  Dispositivos    Kevin   10711
# 15    Oeste  Dispositivos     Sara    8780
# 16    Oeste      Sistemas    Kevin   32855
# 17    Oeste      Sistemas     Sara   23151

# %%
            #paso 5:

# %%
# primeras filas
df.head(5)
# Out:
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 1  Central    Accesorios    Karen    6909
# 2  Central  Dispositivos    David   11420
# 3  Central  Dispositivos    Karen   12948
# 4  Central      Sistemas    David   20098

# %%
# ultimas filas
df.tail(5)
# Out:
#    Region      Producto Vendedor  Ventas
# 13  Oeste    Accesorios     Sara    5442
# 14  Oeste  Dispositivos    Kevin   10711
# 15  Oeste  Dispositivos     Sara    8780
# 16  Oeste      Sistemas    Kevin   32855
# 17  Oeste      Sistemas     Sara   23151

# %%
# inf sobre el df
df.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Region    18 non-null     object
#  1   Producto  18 non-null     object
#  2   Vendedor  18 non-null     object
#  3   Ventas    18 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 704.0+ bytes

# %%
# estadisticas descriptivas
df.describe()
# Out:
#              Ventas
# count     18.000000
# mean   13307.388889
# std     8153.055776
# min     4744.000000
# 25%     8410.250000
# 50%    10529.500000
# 75%    13491.750000
# max    32855.000000

# %%
#devuelve una tupla xfilas y columnas
df.shape
# Out:
# (18, 4)

# %%
#devuelve un lista de las columnas
df.columns
# Out:
# Index(['Region', 'Producto', 'Vendedor', 'Ventas'], dtype='object')

# %%
#Ejercicio2: calcular ventas por region
print("Ejercicio2: calcular ventas por region")
Ventas_por_region = df.groupby('Region')['Ventas'].sum()
print(Ventas_por_region)
print("¨/n")
print(df.head(10))
# Out:
# Ejercicio2: calcular ventas por region
# Region
# Central    90295
# Este       63555
# Oeste      85683
# Name: Ventas, dtype: int64
# ¨/n
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 1  Central    Accesorios    Karen    6909
# 2  Central  Dispositivos    David   11420
# 3  Central  Dispositivos    Karen   12948
# 4  Central      Sistemas    David   20098
# 5  Central      Sistemas    Karen   30633
# 6     Este    Accesorios      Ana    9323
# 7     Este    Accesorios    Lucas    7667
# 8     Este  Dispositivos      Ana   10348
# 9     Este  Dispositivos    Lucas    9312

# %%
# Ejercicio 3:filtrar el df por las ventas de david
print("Ejercicio3:filtrar el df por las ventas de david")
Ventas_david = df[df['Vendedor']=='David']
print(Ventas_david)
print("/n")
# Out:
# Ejercicio3:filtrar el df por las ventas de david
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 2  Central  Dispositivos    David   11420
# 4  Central      Sistemas    David   20098
# /n

# %%
# Ejercicio 4: Promedio de ventas por producto
print("Ejercicio 4: Promedio de ventas por producto")
Ventas_por_producto = df.groupby('Producto')['Ventas'].mean()
print(Ventas_por_producto)
print("/n")
# Out:
# Ejercicio 4: Promedio de ventas por producto
# Producto
# Accesorios       7062.000000
# Dispositivos    10586.500000
# Sistemas        22273.666667
# Name: Ventas, dtype: float64
# /n

# %%
# Ejercicio 5: orden df por ventas en orden decendente
print("Ejercicio 5: orden df por ventas en orden decendente")
df_por_orden = df.sort_values(by='Ventas', ascending=False)
print(df_por_orden)
# Out:
# Ejercicio 5: orden df por ventas en orden decendente
#      Region      Producto Vendedor  Ventas
# 16    Oeste      Sistemas    Kevin   32855
# 5   Central      Sistemas    Karen   30633
# 17    Oeste      Sistemas     Sara   23151
# 4   Central      Sistemas    David   20098
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 3   Central  Dispositivos    Karen   12948
# 2   Central  Dispositivos    David   11420
# 14    Oeste  Dispositivos    Kevin   10711
# 8      Este  Dispositivos      Ana   10348
# 6      Este    Accesorios      Ana    9323
# 9      Este  Dispositivos    Lucas    9312
# 15    Oeste  Dispositivos     Sara    8780
# 0   Central    Accesorios    David    8287
# 7      Este    Accesorios    Lucas    7667
# 1   Central    Accesorios    Karen    6909
# 13    Oeste    Accesorios     Sara    5442
# 12    Oeste    Accesorios    Kevin    4744

# %%
#Ejercicio 6 : filtrar filass co ventas mayores a 10.000
print('Ejercicio 6 : filtrar filass co ventas mayores a 10.000')
df_filtrado= df[df['Ventas']>10000]
print(df_filtrado)
print("/n")
# Out:
# Ejercicio 6 : filtrar filass co ventas mayores a 10.000
#      Region      Producto Vendedor  Ventas
# 2   Central  Dispositivos    David   11420
# 3   Central  Dispositivos    Karen   12948
# 4   Central      Sistemas    David   20098
# 5   Central      Sistemas    Karen   30633
# 8      Este  Dispositivos      Ana   10348
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 14    Oeste  Dispositivos    Kevin   10711
# 16    Oeste      Sistemas    Kevin   32855
# 17    Oeste      Sistemas     Sara   23151
# /n

# %%
#Ejercicio 7: orde el df en orden desendente
print("Ejercicio 7: orden df por ventas en orden decendente")
df_por_orden = df.sort_values(by='Ventas', ascending=True)
print(df_por_orden)
# Out:
# Ejercicio 7: orden df por ventas en orden decendente
#      Region      Producto Vendedor  Ventas
# 12    Oeste    Accesorios    Kevin    4744
# 13    Oeste    Accesorios     Sara    5442
# 1   Central    Accesorios    Karen    6909
# 7      Este    Accesorios    Lucas    7667
# 0   Central    Accesorios    David    8287
# 15    Oeste  Dispositivos     Sara    8780
# 9      Este  Dispositivos    Lucas    9312
# 6      Este    Accesorios      Ana    9323
# 8      Este  Dispositivos      Ana   10348
# 14    Oeste  Dispositivos    Kevin   10711
# 2   Central  Dispositivos    David   11420
# 3   Central  Dispositivos    Karen   12948
# 11     Este      Sistemas    Lucas   13374
# 10     Este      Sistemas      Ana   13531
# 4   Central      Sistemas    David   20098
# 17    Oeste      Sistemas     Sara   23151
# 5   Central      Sistemas    Karen   30633
# 16    Oeste      Sistemas    Kevin   32855

# %%
# Ejercicio 8: eliminar la columna vendedor
print('Ejercicio 8: eliminar la columna vendedor')
df_sin_vendedor = df.drop(columns=['Vendedor'])
print(df_sin_vendedor)
print("/n")
# Out:
# Ejercicio 8: eliminar la columna vendedor
#      Region      Producto  Ventas
# 0   Central    Accesorios    8287
# 1   Central    Accesorios    6909
# 2   Central  Dispositivos   11420
# 3   Central  Dispositivos   12948
# 4   Central      Sistemas   20098
# 5   Central      Sistemas   30633
# 6      Este    Accesorios    9323
# 7      Este    Accesorios    7667
# 8      Este  Dispositivos   10348
# 9      Este  Dispositivos    9312
# 10     Este      Sistemas   13531
# 11     Este      Sistemas   13374
# 12    Oeste    Accesorios    4744
# 13    Oeste    Accesorios    5442
# 14    Oeste  Dispositivos   10711
# 15    Oeste  Dispositivos    8780
# 16    Oeste      Sistemas   32855
# 17    Oeste      Sistemas   23151
# /n

# %% [markdown]
# # **Creacion del df**

# %%
# crear df de pandas
data={
    'id':['1','2','3','4','4','5','6','7'],
    'weight':['144.5','167.2','124.1','144.5','144.5','133.2','124.1','129.2'],
    'height': ['5.9','5.4','5.2','5.9','5.9','5.7','5.2','5.3'],
    'age':    ['33','45','23','33','','54','23','42'],
    'gender': ['m','m','f','m','','f','f','m']
}
df_fpersona= pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Region    18 non-null     object
#  1   Producto  18 non-null     object
#  2   Vendedor  18 non-null     object
#  3   Ventas    18 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 704.0+ bytes

# %%
# filas repetidas
print(f'tamaño antes de eliminar filas repetidas: {df.shape}')
df.drop_duplicates(inplace=True)
print(f'tamaño del set desùes de eliminar filas:{df.shape}')
# Out:
# tamaño antes de eliminar filas repetidas: (18, 4)
# tamaño del set desùes de eliminar filas:(18, 4)

# %%
df_fpersona.head(7)
# Out:
#   id weight height age gender
# 0  1  144.5    5.9  33      m
# 1  2  167.2    5.4  45      m
# 2  3  124.1    5.2  23      f
# 3  4  144.5    5.9  33      m
# 4  4  144.5    5.9
# 5  5  133.2    5.7  54      f
# 6  6  124.1    5.2  23      f
