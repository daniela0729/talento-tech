# %% [markdown]
# <a href="https://colab.research.google.com/github/daniela0729/talento-tech/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive # Traemos la clase drive, dentro del módulo colab, del paquete google
drive.mount('/content/drive') # Establecemos la conexión através del método mount
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Colab Notebooks/ventas .xlsx'
file = 'ventas .xlsx'

# %%
import pandas as pd

# %%
df = pd.read_excel(path)

# %%
df.head(20)
# Out:
#     Unnamed: 0 Unnamed: 1    Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0          NaN     Region      Producto   Vendedor     Ventas
# 1          NaN    Central    Accesorios      David       8287
# 2          NaN    Central    Accesorios      Karen       6909
# 3          NaN    Central  Dispositivos      David      11420
# 4          NaN    Central  Dispositivos      Karen      12948
# 5          NaN    Central      Sistemas      David      20098
# 6          NaN    Central      Sistemas      Karen      30633
# 7          NaN       Este    Accesorios        Ana       9323
# 8          NaN       Este    Accesorios      Lucas       7667
# 9          NaN       Este  Dispositivos        Ana      10348
# 10         NaN       Este  Dispositivos      Lucas       9312
# 11         NaN       Este      Sistemas        Ana      13531
# 12         NaN       Este      Sistemas      Lucas      13374
# 13         NaN      Oeste    Accesorios      Kevin       4744
# 14         NaN      Oeste    Accesorios       Sara       5442
# 15         NaN      Oeste  Dispositivos      Kevin      10711
# 16         NaN      Oeste  Dispositivos       Sara       8780
# 17         NaN      Oeste      Sistemas      Kevin      32855
# 18         NaN      Oeste      Sistemas       Sara      23151
